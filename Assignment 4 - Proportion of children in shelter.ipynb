# %% [markdown]
# *Replace this text with your own name and a brief description of what this notebook does.*

# %% [markdown]
# ## Assignment 4
#
# Write a piece of code that plots a line graph of the proportion of individuals in the shelter that are children using the DHS Daily Report dataset that you downloaded in Lab 2.

# %%
import matplotlib as plt

# %%
import pandas as pd
# %matplotlib inline

# %%
shelter = pd.read_csv("DHS_Daily_Report.csv", parse_dates=["Date of Census"])

# %%
print(shelter)
# Out:
#      Date of Census  Total Adults in Shelter  Total Children in Shelter  \
# 0        2015-01-02                    33162                      25018
# 1        2015-01-03                    33161                      25011
# 2        2015-01-04                    33303                      25027
# 3        2015-01-05                    33354                      25015
# 4        2015-01-06                    33374                      24978
# 5        2015-01-07                    33464                      25010
# 6        2015-01-08                    33517                      25034
# 7        2015-01-09                    33415                      25013
# 8        2015-01-10                    33484                      25003
# 9        2015-01-11                    33569                      25014
# 10       2015-01-12                    33609                      25034
# 11       2015-01-13                    33615                      25013
# ...

# %%
shelter.head()
# Out:
#   Date of Census  Total Adults in Shelter  Total Children in Shelter  \
# 0     2015-01-02                    33162                      25018
# 1     2015-01-03                    33161                      25011
# 2     2015-01-04                    33303                      25027
# 3     2015-01-05                    33354                      25015
# 4     2015-01-06                    33374                      24978
#
#    Total Individuals in Shelter  Single Adult Men in Shelter  \
# 0                         58180                         8136
# 1                         58172                         8148
# 2                         58330                         8218
# 3                         58369                         8237
# 4                         58352                         8276
#
#    Single Adult Women in Shelter  Total Single Adults in Shelter  \
# 0                           3100                           11236
# ...

# %%
shelter.plot( x = "Date of Census", y = "Total Individuals in Shelter")

# %%
y = "Total Individuals in Shelter"

# %%
shelter.plot(x="Date of Census").legend(bbox_to_anchor=(1,1))

# %%
shelter["Total Adults in Shelter"]
# Out:
# 0       33162
# 1       33161
# 2       33303
# 3       33354
# 4       33374
# 5       33464
# 6       33517
# 7       33415
# 8       33484
# 9       33569
# 10      33609
# 11      33615
# 12      33636
# 13      33646
# 14      33621
# 15      33538
# 16      33630
# 17      33687
# 18      33716
# 19      33686
# 20      33711
# 21      33611
# 22      33595
# 23      33708
# 24      33712
# 25      33781
# 26      33774
# 27      33699
# 28      33699
# 29      33602
#         ...
# 1436    38213
# 1437    38211
# 1438    38219
# 1439    38251
# 1440    38383
# 1441    38416
# 1442    38307
# 1443    38345
# 1444    38505
# 1445    38612
# 1446    38564
# 1447    38650
# 1448    38704
# 1449    38751
# 1450    38783
# 1451    38768
# 1452    38807
# 1453    38748
# 1454    38791
# 1455    38830
# 1456    38738
# 1457    38711
# 1458    38773
# 1459    38831
# 1460    38793
# 1461    38794
# 1462    38807
# 1463    38753
# 1464    38731
# 1465    38747
# ...

# %%
shelter["Total Adults in Shelter"]/shelter["Total Individuals in Shelter"]
# Out:
# 0       0.569990
# 1       0.570051
# 2       0.570941
# 3       0.571433
# 4       0.571943
# 5       0.572289
# 6       0.572441
# 7       0.571900
# 8       0.572503
# 9       0.573016
# 10      0.573112
# 11      0.573361
# 12      0.573602
# 13      0.573508
# 14      0.573502
# 15      0.573103
# 16      0.573460
# 17      0.573972
# 18      0.574241
# 19      0.574405
# 20      0.574734
# 21      0.574105
# 22      0.574549
# 23      0.574957
# 24      0.575270
# 25      0.575172
# 26      0.575141
# 27      0.574931
# 28      0.574931
# 29      0.574334
#           ...
# 1436    0.632226
# 1437    0.632109
# 1438    0.631844
# 1439    0.631517
# 1440    0.632162
# 1441    0.632529
# 1442    0.631670
# 1443    0.631797
# 1444    0.632193
# 1445    0.632641
# 1446    0.632539
# 1447    0.632435
# 1448    0.632791
# 1449    0.631865
# 1450    0.631491
# 1451    0.632647
# 1452    0.633532
# 1453    0.633179
# 1454    0.632899
# 1455    0.633463
# 1456    0.633253
# ...

# %%
shelter["Total Adults in Shelter"]/shelter["Total Individuals in Shelter"]
# Out:
# 0       0.569990
# 1       0.570051
# 2       0.570941
# 3       0.571433
# 4       0.571943
# 5       0.572289
# 6       0.572441
# 7       0.571900
# 8       0.572503
# 9       0.573016
# 10      0.573112
# 11      0.573361
# 12      0.573602
# 13      0.573508
# 14      0.573502
# 15      0.573103
# 16      0.573460
# 17      0.573972
# 18      0.574241
# 19      0.574405
# 20      0.574734
# 21      0.574105
# 22      0.574549
# 23      0.574957
# 24      0.575270
# 25      0.575172
# 26      0.575141
# 27      0.574931
# 28      0.574931
# 29      0.574334
#           ...
# 1436    0.632226
# 1437    0.632109
# 1438    0.631844
# 1439    0.631517
# 1440    0.632162
# 1441    0.632529
# 1442    0.631670
# 1443    0.631797
# 1444    0.632193
# 1445    0.632641
# 1446    0.632539
# 1447    0.632435
# 1448    0.632791
# 1449    0.631865
# 1450    0.631491
# 1451    0.632647
# 1452    0.633532
# 1453    0.633179
# 1454    0.632899
# 1455    0.633463
# 1456    0.633253
# ...

# %%
shelter["Proportion Children"] = shelter["Total Children in Shelter"]/shelter["Total Individuals in Shelter"]

# %%
shelter
# Out:
#      Date of Census  Total Adults in Shelter  Total Children in Shelter  \
# 0        2015-01-02                    33162                      25018
# 1        2015-01-03                    33161                      25011
# 2        2015-01-04                    33303                      25027
# 3        2015-01-05                    33354                      25015
# 4        2015-01-06                    33374                      24978
# 5        2015-01-07                    33464                      25010
# 6        2015-01-08                    33517                      25034
# 7        2015-01-09                    33415                      25013
# 8        2015-01-10                    33484                      25003
# 9        2015-01-11                    33569                      25014
# 10       2015-01-12                    33609                      25034
# 11       2015-01-13                    33615                      25013
# ...

# %%
shelter["Proportion Children"] = shelter["Total Children in Shelter"]/shelter["Total Individuals in Shelter"]

# %%
shelter.plot(y = "Proportion Children", x = "Date of Census" )

# %% [markdown]
# 1. What does the graph show about the proportion of individuals who are children in shelters over time?
# 2. Do you notice any other features in the graph?
#
# Write your answers below.

# %%
The graph shows that the proportion of individuals who are children in shelters increases 
and decreases within time, so it's mostly classified as a irregular graph.

# %%
No, I did not really notice any other features in the graph.
